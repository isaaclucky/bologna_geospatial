# %%
import pandas as pd
import numpy as np
from datetime import datetime
import geopandas as gpd
import os, sys

 
sys.path.append(os.path.dirname(os.getcwd()))
from scripts.vehicle_type_model import VehicleTypeModel

# %%
import pyrosm

osm = pyrosm.OSM("../data/land_use/037006_Bologna-2025-03-12T13Z.osm.pbf")
landuse_gdf = osm.get_landuse()
landuse_gdf = landuse_gdf.to_crs("EPSG:32632")

# %%
import matplotlib.pyplot as plt
ax = landuse_gdf.plot(column="landuse", figsize=(12,12), legend=True, legend_kwds=dict(loc='upper left', ncol=3, bbox_to_anchor=(1, 1)))
plt.show()

# %%
vm = VehicleTypeModel(
    traffic_csv="../data/bologna_traffic_time_series.csv",
    meta_csv="../data/bologna_traffic_metadata.csv",
    ltz_shp="../data/ltz_zones/zona-a-traffico-limitato.shp",
    nrows=5000  # Limit to 5000 rows for performance
)
vm.landuse_gdf = landuse_gdf  
vm.run_full_pipeline()
# Out:
# Validation passed!
# Processing complete!

# %%
vm.results
# Out:
#         datetime  id_uni  Level  VAN_count  BOX_TRUCK_count  TRUCK_count  \
# 0     2024-04-24     450      1         37                8            4
# 1     2024-04-24     362      1         74               16            8
# 2     2024-04-24     753      1        172               36           18
# 3     2024-04-24     456      1          0                0            0
# 4     2024-04-24     323      1        160               34           17
# ...          ...     ...    ...        ...              ...          ...
# 49995 2024-07-30     130      1         44                9            5
# 49996 2024-08-01     227      1         14                3            2
# 49997 2024-07-30     110      1        194               41           20
# 49998 2024-08-01     229      1        136               33           17
# 49999 2024-07-30     612      1         37                8            4
#
#        proportion_VAN  proportion_BOX_TRUCK  proportion_TRUCK
# 0            0.760000              0.160000          0.080000
# 1            0.760000              0.160000          0.080000
# 2            0.760000              0.160000          0.080000
# 3            0.760000              0.160000          0.080000
# 4            0.760000              0.160000          0.080000
# ...               ...                   ...               ...
# 49995        0.760000              0.160000          0.080000
# 49996        0.730769              0.176923          0.092308
# 49997        0.760000              0.160000          0.080000
# 49998        0.730769              0.176923          0.092308
# 49999        0.760000              0.160000          0.080000
#
# [50000 rows x 9 columns]
