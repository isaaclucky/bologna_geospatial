# %%
import geopandas as gpd
import pyrosm
import matplotlib.pyplot as plt

# %%
osm = pyrosm.OSM("../data/land_use/037006_Bologna-2025-03-12T13Z.osm.pbf")


landuse = osm.get_landuse()
landuse.plot(column='landuse', legend=True, figsize=(12,12))
plt.show()

# %%
landuse.head(2).to_dict()
# Out:
# {'construction': {0: None, 1: None},
#  'depot': {0: None, 1: None},
#  'industrial': {0: None, 1: None},
#  'landuse': {0: 'commercial', 1: 'retail'},
#  'meadow': {0: None, 1: None},
#  'military': {0: None, 1: None},
#  'residential': {0: None, 1: None},
#  'id': {0: 23189490, 1: 27456592},
#  'timestamp': {0: 1733619193, 1: 1685871222},
#  'version': {0: 23, 1: 3},
#  'geometry': {0: <POLYGON ((11.369 44.513, 11.371 44.511, 11.371 44.511, 11.371 44.511, 11.37...>,
#   1: <POLYGON ((11.354 44.484, 11.354 44.484, 11.354 44.484, 11.354 44.484, 11.35...>},
#  'tags': {0: '{"visible":false,"amenity":"exhibition_centre","name":"Fiera di Bologna","name:de":"Messe Bologna","name:en":"Trade Fair Bologna","name:it":"Fiera di Bologna","website":"https://www.bolognafiere.it/","wikidata":"Q3074846","wikipedia":"it:Fiera di Bologna"}',
#   1: '{"visible":false}'},
#  'osm_type': {0: 'way', 1: 'way'},
#  'changeset': {0: nan, 1: nan}}
